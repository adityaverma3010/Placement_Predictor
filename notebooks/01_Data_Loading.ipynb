# %%
import sys
from pathlib import Path

project_root = Path().resolve().parent

if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# %%
import src.data_loader

# %%
import pandas as pd
import logging
import src.logger
from src.exception import CustomException
from src.data_loader import DataLoader
from config.config import DATA_PATH

import sys

# %%
import importlib
import config.config

importlib.reload(config.config)

print(config.config.DATA_PATH)
print(config.config.DATA_PATH.exists())
# Out:
# C:\Users\Aditya Verma\OneDrive\Desktop\Placement _Predictor\data\raw\college_student_placement_dataset.csv
# True

# %%
from config.config import DATA_PATH

print(DATA_PATH)
print(DATA_PATH.exists())
# Out:
# C:\Users\Aditya Verma\OneDrive\Desktop\Placement _Predictor\data\raw\college_student_placement_dataset.csv
# True

# %%
from pathlib import Path

try:

    if Path(DATA_PATH).exists():

        logging.info("Dataset Found Successfully.")

        print("Dataset Found")

    else:

        logging.error("Dataset Not Found.")

        raise FileNotFoundError("Dataset does not exist.")

except Exception as e:

    logging.error(e)

    raise CustomException(e, sys)
# Out:
# 2026-07-21 22:40:05,846 - INFO - Dataset Found Successfully.
# Dataset Found

# %%
loader = DataLoader(DATA_PATH)

df = loader.load_data()
# Out:
# 2026-07-21 22:40:07,084 - INFO - ============================================================
# 2026-07-21 22:40:07,085 - INFO - DATA LOADING STARTED
# 2026-07-21 22:40:07,086 - INFO - ============================================================
# 2026-07-21 22:40:07,087 - INFO - Dataset Found
# 2026-07-21 22:40:07,089 - INFO - Dataset is not empty
# 2026-07-21 22:40:07,142 - INFO - Dataset Loaded Successfully
# 2026-07-21 22:40:07,147 - INFO - Dataset Shape : (10000, 10)
# 2026-07-21 22:40:07,148 - INFO - Columns : ['College_ID', 'IQ', 'Prev_Sem_Result', 'CGPA', 'Academic_Performance', 'Internship_Experience', 'Extra_Curricular_Score', 'Communication_Skills', 'Projects_Completed', 'Placement']
# 2026-07-21 22:40:07,151 - INFO - ============================================================
# 2026-07-21 22:40:07,155 - INFO - DATA LOADING COMPLETED
# 2026-07-21 22:40:07,157 - INFO - ============================================================

# %%
logging.info("Displaying first five rows.")

df.head()
# Out:
# 2026-07-21 22:40:08,433 - INFO - Displaying first five rows.
#   College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0    CLG0030  107             6.61  6.28                     8
# 1    CLG0061   97             5.52  5.37                     8
# 2    CLG0036  109             5.36  5.83                     9
# 3    CLG0055  122             5.47  5.75                     6
# 4    CLG0004   96             7.91  7.69                     7
#
#   Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                    No                       8                     8
# 1                    No                       7                     8
# 2                    No                       3                     1
# 3                   Yes                       1                     6
# 4                    No                       8                    10
#
#    Projects_Completed Placement
# 0                   4        No
# 1                   0        No
# ...

# %%
logging.info("Checking Dataset Shape")

print(df.shape)
# Out:
# 2026-07-21 22:40:12,612 - INFO - Checking Dataset Shape
# (10000, 10)

# %%
logging.info("Displaying Dataset Information")

df.info()
# Out:
# 2026-07-21 22:40:13,421 - INFO - Displaying Dataset Information
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   College_ID              10000 non-null  str
#  1   IQ                      10000 non-null  int64
#  2   Prev_Sem_Result         10000 non-null  float64
#  3   CGPA                    10000 non-null  float64
#  4   Academic_Performance    10000 non-null  int64
#  5   Internship_Experience   10000 non-null  str
#  6   Extra_Curricular_Score  10000 non-null  int64
#  7   Communication_Skills    10000 non-null  int64
#  8   Projects_Completed      10000 non-null  int64
#  9   Placement               10000 non-null  str
# dtypes: float64(2), int64(5), str(3)
# memory usage: 894.3 KB

# %%
logging.info("Checking Missing Values")

df.isnull().sum()
# Out:
# 2026-07-21 22:40:14,329 - INFO - Checking Missing Values
# College_ID                0
# IQ                        0
# Prev_Sem_Result           0
# CGPA                      0
# Academic_Performance      0
# Internship_Experience     0
# Extra_Curricular_Score    0
# Communication_Skills      0
# Projects_Completed        0
# Placement                 0
# dtype: int64

# %%
logging.info("Checking Duplicate Records")

print(df.duplicated().sum())
# Out:
# 2026-07-21 22:40:15,040 - INFO - Checking Duplicate Records
# 0

# %%
logging.info("Displaying Data Types")

df.dtypes
# Out:
# 2026-07-21 22:40:17,798 - INFO - Displaying Data Types
# College_ID                    str
# IQ                          int64
# Prev_Sem_Result           float64
# CGPA                      float64
# Academic_Performance        int64
# Internship_Experience         str
# Extra_Curricular_Score      int64
# Communication_Skills        int64
# Projects_Completed          int64
# Placement                     str
# dtype: object
